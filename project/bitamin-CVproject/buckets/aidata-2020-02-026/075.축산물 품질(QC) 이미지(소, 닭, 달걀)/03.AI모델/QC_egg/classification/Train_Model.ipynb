# %%
# !python train.py --model_name eff_b7 --exp v1 --gpu 0 --batch_size 64 --pretrained True
# Out:
# model name: eff_b7
# Explanation: v1
# num_workers: 24
# n_epochs: 200
# batch_size: 64
# Resize- Height: 512, Width: 512
#
# => using pre-trained model eff_b7
# Loaded pretrained weights for efficientnet-b7
# Let's use 4 GPUs!
# BCEWithLogitsLoss()
# optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.001
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0.0005
# )
# Compose([
#   Resize(always_apply=False, p=1, height=512, width=512, interpolation=1),
#   HorizontalFlip(always_apply=False, p=0.4),
#   VerticalFlip(always_apply=False, p=0.4),
#   RandomRotate90(always_apply=False, p=0.4),
#   RandomGridShuffle(always_apply=False, p=0.4, grid=(3, 3)),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
#
# train size : 24340
# valid size : 3040
# test size : 3043
#
# ##------Epoch 1
# [+] Train Accuracy: 64.243,  Train Loss: 0.3196
# ...
